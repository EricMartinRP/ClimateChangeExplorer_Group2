# %%
#import dependices
from wwo_hist import retrieve_hist_data
import os

# %%
#working directory 
os.chdir(r"C:\Users\EMARTIN8169\OneDrive\Desktop\OSUFOLDER\ClimateChangeExplorer_Group2\StateWeatherFolder")

# %%
#data pull 
frequency=24
start_date = '01-JAN-2010'
end_date = '30-MAR-2023'
api_key = 'd5468568b45b48ca92c13659230206'
location_list = ['wyoming'] 

#'tennessee','texas','utah','vermont','virginia','washington','west virginia','wisconsin','wyoming'

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for wyoming
#
#
# Currently retrieving data for wyoming: from 2010-01-01 to 2010-01-31
# c:\Users\EMARTIN8169\anaconda3\lib\site-packages\wwo_hist\__init__.py:69: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# c:\Users\EMARTIN8169\anaconda3\lib\site-packages\wwo_hist\__init__.py:74: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:01.100717
# Currently retrieving data for wyoming: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:02.031595
# Currently retrieving data for wyoming: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.988688
# Currently retrieving data for wyoming: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.976308
# ...
